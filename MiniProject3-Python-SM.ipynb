# %%
#Stevland Matthew MINI PROJECT PYTHON 2/11/2022

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install XlsxWriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Missing values fuctuntion to remove NAN data

# %%
miss_values = ["n/a","na","s"]

# %%
#Reading in raw data for NYC schools removing missing values

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = miss_values)

# %%
df1=df[df['School Level'] == 'High school']

# %%
#Created a new dataframe df1 and filtered dataframe to only return only schools at the HIGHSCHOOL level

# %%
df1
# Out:
#        School DBN                           School Name School Level  \
# 18         01M292            Orchard Collegiate Academy  High school
# 19         01M292            Orchard Collegiate Academy  High school
# 20         01M292            Orchard Collegiate Academy  High school
# 21         01M292            Orchard Collegiate Academy  High school
# 22         01M292            Orchard Collegiate Academy  High school
# ...           ...                                   ...          ...
# 212096     84X581  South Bronx Community Charter School  High school
# 212097     84X581  South Bronx Community Charter School  High school
# 212098     84X581  South Bronx Community Charter School  High school
# 212099     84X581  South Bronx Community Charter School  High school
# 212100     84X581  South Bronx Community Charter School  High school
#
#                  Regents Exam  Year  Total Tested  Mean Score  \
# 18      Algebra2/Trigonometry  2015             5         NaN
# ...

# %%
#Created a new dataframe df2 from df1 and filtered dataframe to only return  exams for Algebra2/Trigonometry

# %%
df2=df1[df['Regents Exam'] == 'Algebra2/Trigonometry']
# Out:
# <ipython-input-12-614089113a5f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2=df1[df['Regents Exam'] == 'Algebra2/Trigonometry']

# %%
df2
# Out:
#        School DBN                                        School Name  \
# 18         01M292                         Orchard Collegiate Academy
# 19         01M292                         Orchard Collegiate Academy
# 59         01M448                University Neighborhood High School
# 60         01M448                University Neighborhood High School
# 61         01M448                University Neighborhood High School
# ...           ...                                                ...
# 211972     84X553  New Visions Charter High School for the Humani...
# 211973     84X553  New Visions Charter High School for the Humani...
# 211974     84X553  New Visions Charter High School for the Humani...
# 211975     84X553  New Visions Charter High School for the Humani...
# 211976     84X553  New Visions Charter High School for the Humani...
#
#        School Level           Regents Exam  Year  Total Tested  Mean Score  \
# ...

# %%
#Created a new dataframe df3 from df3 and filtered dataframe to only return SCHOOL NAME University Neighborhood High School

# %%
dfs=df[df['Year'] == '2015']

# %%
df3=df2[df['School Name'] == 'University Neighborhood High School']
# Out:
# <ipython-input-16-066cf57ee305>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3=df2[df['School Name'] == 'University Neighborhood High School']

# %%
df3
# Out:
#        School DBN                          School Name School Level  \
# 59         01M448  University Neighborhood High School  High school
# 60         01M448  University Neighborhood High School  High school
# 61         01M448  University Neighborhood High School  High school
# 19574      01M448  University Neighborhood High School  High school
# 19575      01M448  University Neighborhood High School  High school
# 19576      01M448  University Neighborhood High School  High school
# 19577      01M448  University Neighborhood High School  High school
# 19578      01M448  University Neighborhood High School  High school
# 54380      01M448  University Neighborhood High School  High school
# 54381      01M448  University Neighborhood High School  High school
# 54382      01M448  University Neighborhood High School  High school
# 54383      01M448  University Neighborhood High School  High school
# 54384      01M448  University Neighborhood High School  High school
# ...

# %% [markdown]
# # Groupby year to see how many students were tested at University Neighborhood High School each year

# %%
df3.groupby(['Year'])['Total Tested'].sum()
# Out:
# Year
# 2015    225
# 2016    275
# 2017     55
# Name: Total Tested, dtype: int64

# %%
sns.stripplot(x='Year', y='Total Tested', data=df3)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Tested'>

# %%
#Mean score by year for University Neighborhood High School in Algebra2/Trigonometry for 2015 2016 2017

# %%
df3.groupby(['Year'])['Mean Score'].mean()
# Out:
# Year
# 2015    62.875000
# 2016    61.462500
# 2017    58.266667
# Name: Mean Score, dtype: float64

# %%
sns.barplot(x='Year', y='Mean Score', data=df3)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Mean Score'>

# %%
#All highschool total tested students from 2015-2017 for Algebra2/Trigonometry

# %%
df2.groupby(['Year'])['Total Tested'].sum()
# Out:
# Year
# 2015    153145
# 2016    145985
# 2017     14110
# Name: Total Tested, dtype: int64

# %%
df2.groupby(['Year'])['Mean Score'].mean()
# Out:
# Year
# 2015    56.952520
# 2016    56.239245
# 2017    52.770825
# Name: Mean Score, dtype: float64

# %%
sns.barplot(x='Year', y='Mean Score', data=df2)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Mean Score'>

# %%
#Mean score of all highschools for exam Algebra2/Trigonometry

# %%
sns.barplot(x='Mean Score', data=df2)
# Out:
# <AxesSubplot:xlabel='Mean Score'>

# %%
#From the data analysis above University Neighborhood High School' tested more students for Algebra2/Trigonometry in 2016 but had a higher mean score in 2015. Also University Neighborhood High School had 
#mean score than all other school testing Algebra2/Trigonometry

# %%
df1
# Out:
#        School DBN                           School Name School Level  \
# 18         01M292            Orchard Collegiate Academy  High school
# 19         01M292            Orchard Collegiate Academy  High school
# 20         01M292            Orchard Collegiate Academy  High school
# 21         01M292            Orchard Collegiate Academy  High school
# 22         01M292            Orchard Collegiate Academy  High school
# ...           ...                                   ...          ...
# 212096     84X581  South Bronx Community Charter School  High school
# 212097     84X581  South Bronx Community Charter School  High school
# 212098     84X581  South Bronx Community Charter School  High school
# 212099     84X581  South Bronx Community Charter School  High school
# 212100     84X581  South Bronx Community Charter School  High school
#
#                  Regents Exam  Year  Total Tested  Mean Score  \
# 18      Algebra2/Trigonometry  2015             5         NaN
# ...

# %%
#created a nee datafram df4 from df1 for new anaylsis still dealing with only HIGHSCHOOLS

# %%
df4= df1[['School DBN','School Name','School Level','Regents Exam','Year','Total Tested','Mean Score','Percent Scoring Below 65','Percent Scoring 80 or Above']]

# %%
df4
# Out:
#        School DBN                           School Name School Level  \
# 18         01M292            Orchard Collegiate Academy  High school
# 19         01M292            Orchard Collegiate Academy  High school
# 20         01M292            Orchard Collegiate Academy  High school
# 21         01M292            Orchard Collegiate Academy  High school
# 22         01M292            Orchard Collegiate Academy  High school
# ...           ...                                   ...          ...
# 212096     84X581  South Bronx Community Charter School  High school
# 212097     84X581  South Bronx Community Charter School  High school
# 212098     84X581  South Bronx Community Charter School  High school
# 212099     84X581  South Bronx Community Charter School  High school
# 212100     84X581  South Bronx Community Charter School  High school
#
#                  Regents Exam  Year  Total Tested  Mean Score  \
# 18      Algebra2/Trigonometry  2015             5         NaN
# ...

# %%
#Created a new dataframe df5 from df4 dropping all rows that have NAN values

# %%
df5=df4.dropna(0)

# %%
df5.head(10)
# Out:
#    School DBN                 School Name School Level          Regents Exam  \
# 20     01M292  Orchard Collegiate Academy  High school   Common Core Algebra
# 21     01M292  Orchard Collegiate Academy  High school   Common Core Algebra
# 22     01M292  Orchard Collegiate Academy  High school   Common Core Algebra
# 23     01M292  Orchard Collegiate Academy  High school  Common Core Algebra2
# 25     01M292  Orchard Collegiate Academy  High school   Common Core English
# 26     01M292  Orchard Collegiate Academy  High school   Common Core English
# 27     01M292  Orchard Collegiate Academy  High school   Common Core English
# 28     01M292  Orchard Collegiate Academy  High school  Common Core Geometry
# 30     01M292  Orchard Collegiate Academy  High school  Common Core Geometry
# 31     01M292  Orchard Collegiate Academy  High school               English
#
#     Year  Total Tested  Mean Score  Percent Scoring Below 65  \
# ...

# %%
dfs1[dfs['School DBN']. str.contains ('M')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-489950878dd2> in <module>
# ----> 1 dfs1[dfs['School DBN']. str.contains ('M')]
#
# NameError: name 'dfs1' is not defined

# %%
df6=df5[df5['School Name']. str.contains ('Charter')]

# %%
df7=df6[df6['Regents Exam']. str.contains ('Common Core Algebra')]

# %%
df7=df6[df6['Regents Exam']. str.contains ('Common Core Algebra')]

# %%
df7
# Out:
#        School DBN                                        School Name  \
# 17687      84K359                             The Uft Charter School
# 17688      84K359                             The Uft Charter School
# 17689      84K359                             The Uft Charter School
# 17735      84K395                             Roads Charter School I
# 17736      84K395                             Roads Charter School I
# ...           ...                                                ...
# 211987     84X553  New Visions Charter High School for the Humani...
# 211988     84X553  New Visions Charter High School for the Humani...
# 211989     84X553  New Visions Charter High School for the Humani...
# 211992     84X553  New Visions Charter High School for the Humani...
# 211996     84X553  New Visions Charter High School for the Humani...
#
#        School Level          Regents Exam  Year  Total Tested  Mean Score  \
# ...

# %%
df7.groupby(['School Name'])['Percent Scoring 80 or Above'].mean()
# Out:
# School Name
# Broome Street Academy Charter School                   0.958333
# Charter High School for Law and Social Justice         7.618750
# International Leadership Charter High School          25.120000
# John V. Lindsay Wildcat Academy Charter School        14.085714
# Math, Engineering, and Science Academy Charter Hig     5.532653
# NYC Charter High School for Architecture, Engineer    10.400000
# New Dawn Charter High School                           0.000000
# New Ventures Charter School                            0.000000
# New Visions Charter High School for Advanced Math      6.637255
# New Visions Charter High School for the Humanities     1.187387
# Northside Charter High School                          1.024444
# ROADS Charter School II                                0.000000
# Renaissance Charter High School for Innovation         2.546667
# Roads Charter School I                                 0.000000
# ...

# %%
df7.groupby(['School Name'])['Total Tested'].sum()
# Out:
# School Name
# Broome Street Academy Charter School                   1832
# Charter High School for Law and Social Justice         1039
# International Leadership Charter High School            975
# John V. Lindsay Wildcat Academy Charter School          323
# Math, Engineering, and Science Academy Charter Hig     2760
# NYC Charter High School for Architecture, Engineer     2532
# New Dawn Charter High School                           1028
# New Ventures Charter School                              10
# New Visions Charter High School for Advanced Math     11136
# New Visions Charter High School for the Humanities     9451
# Northside Charter High School                          2597
# ROADS Charter School II                                 579
# Renaissance Charter High School for Innovation         2269
# Roads Charter School I                                  506
# South Bronx Community Charter School                     24
# ...

# %%
sns.barplot(x='Year', y='Mean Score', data=df7)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Mean Score'>

# %%
#2017 all charter highschool show they scored higher in 2017 and increased score each year

# %%
sns.violinplot(x='Year', y='Mean Score', data=df7)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Mean Score'>

# %%
#all charter school mean score for common alegbra. Cool graph below not sure how to size

# %%
sns.barplot(x='Regents Exam', y='Mean Score', data=df6)
# Out:
# <AxesSubplot:xlabel='Regents Exam', ylabel='Mean Score'>

# %%
sns.pointplot(x='Year', y='Mean Score', data=df6)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Mean Score'>

# %%
# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(x='Year', y='Total Tested', linewidth=2.0, data=df3)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
dfs2.tail(20)

# %%
sns.barplot(x="Year" ,y="Total Tested",  data=dfs2)

# %%
dfs.head()

# %%
sns.boxplot (x="Tested", y="Mean Score", hue="Year" , data=dfs2)
