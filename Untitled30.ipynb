# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('US-Gun-Violence.csv')
df
# Out:
#       incident_id     incident_date       state    city_or_county  \
# 0          809815      April 1 2017  California         Pittsburg
# 1          809048      April 1 2017     Florida             Tampa
# 2          809499      April 1 2017    Oklahoma     Oklahoma City
# 3         1083011      April 1 2018     Alabama            Mobile
# 4         1082835      April 1 2018    Michigan           Saginaw
# ...           ...               ...         ...               ...
# 3386      1206409  September 9 2018    Illinois             Elgin
# 3387      1206375  September 9 2018     Alabama            Auburn
# 3388      1206476  September 9 2018     Florida      Jacksonville
# 3389      2111858  September 9 2021    Illinois  East Saint Louis
# 3390      2112252  September 9 2021     Alabama        Montgomery
#
#                               address  killed  injured
# 0        100 block of Madoline Street       0      5.0
# 1                    219 S Howard Ave       1      4.0
# ...

# %%
df.isnull().sum()
# Out:
# incident_id       0
# incident_date     0
# state             0
# city_or_county    0
# address           5
# killed            0
# injured           2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3391 entries, 0 to 3390
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   incident_id     3391 non-null   int64
#  1   incident_date   3391 non-null   object
#  2   state           3391 non-null   object
#  3   city_or_county  3391 non-null   object
#  4   address         3386 non-null   object
#  5   killed          3391 non-null   int64
#  6   injured         3389 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 185.6+ KB

# %%
df.groupby(['state'])['incident_id'].count().sort_values(ascending=False)
# Out:
# state
# Illinois                361
# California              320
# Texas                   221
# Florida                 206
# New York                159
# Pennsylvania            157
# Louisiana               151
# Ohio                    136
# Georgia                 129
# Missouri                112
# Tennessee               109
# Michigan                104
# Maryland                102
# North Carolina           94
# Alabama                  89
# New Jersey               84
# South Carolina           83
# Virginia                 77
# Indiana                  70
# Mississippi              65
# District of Columbia     56
# Colorado                 47
# Kentucky                 39
# Arkansas                 39
# Wisconsin                37
# Minnesota                37
# Arizona                  34
# Washington               34
# Massachusetts            31
# Nevada                   26
# Connecticut              25
# Oklahoma                 22
# New Mexico               20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3391 entries, 0 to 3390
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   incident_id     3391 non-null   int64
#  1   incident_date   3391 non-null   object
#  2   state           3391 non-null   object
#  3   city_or_county  3391 non-null   object
#  4   address         3386 non-null   object
#  5   killed          3391 non-null   int64
#  6   injured         3389 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 185.6+ KB

# %%
df=df.drop(columns=['address'])

# %%
df
# Out:
#       incident_id     incident_date       state    city_or_county  killed  \
# 0          809815      April 1 2017  California         Pittsburg       0
# 1          809048      April 1 2017     Florida             Tampa       1
# 2          809499      April 1 2017    Oklahoma     Oklahoma City       2
# 3         1083011      April 1 2018     Alabama            Mobile       1
# 4         1082835      April 1 2018    Michigan           Saginaw       0
# ...           ...               ...         ...               ...     ...
# 3386      1206409  September 9 2018    Illinois             Elgin       1
# 3387      1206375  September 9 2018     Alabama            Auburn       1
# 3388      1206476  September 9 2018     Florida      Jacksonville       0
# 3389      2111858  September 9 2021    Illinois  East Saint Louis       0
# 3390      2112252  September 9 2021     Alabama        Montgomery       1
#
#       injured
# 0         5.0
# 1         4.0
# 2         3.0
# 3         4.0
# ...

# %%
df.dtypes
# Out:
# incident_id         int64
# incident_date      object
# state              object
# city_or_county     object
# killed              int64
# injured           float64
# dtype: object

# %%
df = df.convert_dtypes()

# %%
df.dtypes
# Out:
# incident_id        Int64
# incident_date     string
# state             string
# city_or_county    string
# killed             Int64
# injured            Int64
# dtype: object

# %%
df
# Out:
#       incident_id     incident_date       state    city_or_county  killed  \
# 0          809815      April 1 2017  California         Pittsburg       0
# 1          809048      April 1 2017     Florida             Tampa       1
# 2          809499      April 1 2017    Oklahoma     Oklahoma City       2
# 3         1083011      April 1 2018     Alabama            Mobile       1
# 4         1082835      April 1 2018    Michigan           Saginaw       0
# ...           ...               ...         ...               ...     ...
# 3386      1206409  September 9 2018    Illinois             Elgin       1
# 3387      1206375  September 9 2018     Alabama            Auburn       1
# 3388      1206476  September 9 2018     Florida      Jacksonville       0
# 3389      2111858  September 9 2021    Illinois  East Saint Louis       0
# 3390      2112252  September 9 2021     Alabama        Montgomery       1
#
#       injured
# 0           5
# 1           4
# 2           3
# 3           4
# ...

# %%
df.to_csv(r'C:\Users\SMatthew\OneDrive - Healthfirst\Documents\Stevie\LGCCC\capstSM.csv')

# %%
df.groupby(['state'])['killed'].count().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='state'>

# %%
df
# Out:
#       incident_id     incident_date       state    city_or_county  killed  \
# 0          809815      April 1 2017  California         Pittsburg       0
# 1          809048      April 1 2017     Florida             Tampa       1
# 2          809499      April 1 2017    Oklahoma     Oklahoma City       2
# 3         1083011      April 1 2018     Alabama            Mobile       1
# 4         1082835      April 1 2018    Michigan           Saginaw       0
# ...           ...               ...         ...               ...     ...
# 3386      1206409  September 9 2018    Illinois             Elgin       1
# 3387      1206375  September 9 2018     Alabama            Auburn       1
# 3388      1206476  September 9 2018     Florida      Jacksonville       0
# 3389      2111858  September 9 2021    Illinois  East Saint Louis       0
# 3390      2112252  September 9 2021     Alabama        Montgomery       1
#
#       injured
# 0           5
# 1           4
# 2           3
# 3           4
# ...
